# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha8112/Files_Pandas/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3659886d-5e8b-46ee-b7a8-649434d30427" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3659886d-5e8b-46ee-b7a8-649434d30427">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Bengaluru_Ride_Data.csv")
print(df)
# Out:
#            Date      Time Booking ID         Booking Status Customer ID  \
# 0    2025-08-31  00:00:00    BKG1000  Cancelled by Customer    CUST2000
# 1    2025-08-08  07:00:00    BKG1001                Success    CUST2001
# 2    2025-08-05  13:00:00    BKG1002                Success    CUST2002
# 3    2025-08-19  07:00:00    BKG1003                Success    CUST2003
# 4    2025-08-29  05:00:00    BKG1004                Success    CUST2004
# ..          ...       ...        ...                    ...         ...
# 295  2025-08-30  19:00:00    BKG1295                Success    CUST2295
# 296  2025-08-10  03:00:00    BKG1296             Incomplete    CUST2296
# 297  2025-08-10  21:00:00    BKG1297                Success    CUST2297
# 298  2025-08-27  21:00:00    BKG1298             Incomplete    CUST2298
# 299  2025-08-27  01:00:00    BKG1299                Success    CUST2299
#
#     Vehicle Type        Pickup Location          Drop Location  Avg VTAT  \
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-522f1522-6875-4e95-bbbe-1af7fea7cd7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-522f1522-6875-4e95-bbbe-1af7fea7cd7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel("AVERAGEIF.xlsx")
print(df)
# Out:
#          Date Transaction Type Debit/Credit  Amount  Unnamed: 4       TOTAL  \
# 0  2023-10-15           Online        Debit    9847         NaN      Online
# 1  2023-10-16             Cash       Credit    7361         NaN        Cash
# 2  2023-10-17           Online        Debit    4532         NaN  Debit Card
# 3  2023-10-18             Cash        Debit    7497         NaN         NaN
# 4  2023-10-19           Online       Credit    4127         NaN         NaN
# 5  2023-10-20       Debit Card        Debit    9417         NaN         NaN
# 6  2023-10-21             Cash       Credit    7648         NaN         NaN
# 7  2023-10-22             Cash       Credit    8563         NaN         NaN
# 8  2023-10-23       Debit Card        Debit    9476         NaN         NaN
# 9  2023-10-24       Debit Card        Debit    9161         NaN         NaN
# 10 2023-10-25           Online       Credit    6919         NaN         NaN
# ...

# %%
import pandas as pd
df = pd.read_json("sample_data.json")
print(df)
# Out:
#    id   name          role  salary
# 0   1   Asha  Data Analyst   45000
# 1   2  Rohit     Developer   55000
# 2   3   Neha   MCA Student       0

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-173abb6f-9415-408a-83d8-6a69a24f2e04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-173abb6f-9415-408a-83d8-6a69a24f2e04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_table("sample_data.tsv")
print(df)
# Out:
#    id   name          role  salary
# 0   1   Asha  Data Analyst   45000
# 1   2  Rohit     Developer   55000
# 2   3   Neha   MCA Student       0

# %%
import pandas as pd
df=pd.read_html("index.html")
print(df)
# Out:
# [   id   name          role  salary
# 0   1   Asha  Data Analyst   45000
# 1   2  Rohit     Developer   55000
# 2   3   Neha   MCA Student       0]
